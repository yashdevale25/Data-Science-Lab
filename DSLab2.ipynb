# %% [markdown]
# <a href="https://colab.research.google.com/github/yashdevale25/Data-Science-Lab/blob/main/DSLab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science LAB 2
# Pre-requisiteTest

# %%
# Python Program For BFS

from collections import deque

def bfs(graph, start_node):
    visited = set()
    queue = deque([start_node])
    visited.add(start_node)

    while queue:
        current_node = queue.popleft()
        print(current_node, end=' ')

        for neighbor in graph.get(current_node, []):
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

# Example Usage:
if __name__ == "__main__":
    # Represent the graph using an adjacency list
    graph = {
        'A': ['B', 'C'],
        'B': ['D', 'E'],
        'C': ['F'],
        'D': [],
        'E': ['F'],
        'F': []
    }

    print("BFS Traversal starting from node 'A':")
    bfs(graph, 'A')
    print()

    graph2 = {
        0: [1, 2],
        1: [2],
        2: [0, 3],
        3: [3]
    }
    print("BFS Traversal starting from node 2 (second example):")
    bfs(graph2, 2)
    print()
# Out:
# BFS Traversal starting from node 'A':
# A B C D E F
# BFS Traversal starting from node 2 (second example):
# 2 0 3 1

# %%
# Python Program For DFS

def dfs(graph, start_node, visited=None):
    if visited is None:
        visited = set()

    visited.add(start_node)
    print(start_node, end=' ')

    for neighbor in graph.get(start_node, []):
        if neighbor not in visited:
            dfs(graph, neighbor, visited)

# Example Usage:
if __name__ == "__main__":
    # Represent the graph using an adjacency list
    graph = {
        'A': ['B', 'C'],
        'B': ['D', 'E'],
        'C': ['F'],
        'D': [],
        'E': ['F'],
        'F': []
    }

    print("DFS Traversal starting from node 'A':")
    dfs(graph, 'A')
    print()

    graph2 = {
        0: [1, 2],
        1: [2],
        2: [0, 3],
        3: [3]
    }
    print("DFS Traversal starting from node 2 (second example):")
    dfs(graph2, 2)
    print()
# Out:
# DFS Traversal starting from node 'A':
# A B D E F C
# DFS Traversal starting from node 2 (second example):
# 2 0 1 3

# %%
# Python Program A* algorithm

import heapq

def a_star_search(start_node, goal_node):
    # The open list (priority queue) stores (f_cost, node, path)
    # f_cost = g_cost + h_cost
    open_list = []
    heapq.heappush(open_list, (0, start_node, [start_node]))

    # g_cost (cost from start to current node)
    g_costs = {start_node: 0}

    # closed list (nodes already visited)
    closed_list = set()

    while open_list:
        f_cost, current_node, path = heapq.heappop(open_list)

        if current_node == goal_node:
            return path, f_cost

        if current_node in closed_list:
            continue

        closed_list.add(current_node)

        for neighbor in get_neighbors(current_node):
            if neighbor in closed_list:
                continue

            # Calculate tentative g_cost for the neighbor
            tentative_g_cost = g_costs[current_node] + cost(current_node, neighbor)

            if neighbor not in g_costs or tentative_g_cost < g_costs[neighbor]:
                g_costs[neighbor] = tentative_g_cost
                h_cost = heuristic(neighbor, goal_node)
                f_cost = tentative_g_cost + h_cost
                new_path = path + [neighbor]
                heapq.heappush(open_list, (f_cost, neighbor, new_path))

    return None, -1 # No path found

# --- Helper functions (to be implemented based on your problem) ---

def heuristic(node, goal_node):
    # Estimates the cost from 'node' to 'goal_node'
    # This is often the Manhattan distance or Euclidean distance in grid-based problems
    # Must be admissible (never overestimates the actual cost)
    # For a simple example, let's just return 0 (equivalent to Dijkstra's algorithm)
    return 0

def get_neighbors(node):
    # Returns a list of neighboring nodes reachable from 'node'
    # For a simple example, we'll return some dummy neighbors
    if node == 'A':
        return ['B', 'C']
    elif node == 'B':
        return ['A', 'D', 'E']
    elif node == 'C':
        return ['A', 'F']
    elif node == 'D':
        return ['B', 'G']
    elif node == 'E':
        return ['B', 'G']
    elif node == 'F':
        return ['C', 'G']
    else:
        return []

def cost(node1, node2):
    # Returns the cost of moving from 'node1' to 'node2'
    # For a simple example, let's assume all costs are 1
    return 1

# Example Usage:
if __name__ == "__main__":
    start = 'A'
    goal = 'G'

    print(f"Starting A* search from {start} to {goal}...")
    path, total_cost = a_star_search(start, goal)

    if path:
        print(f"Path found: {' -> '.join(path)}")
        print(f"Total cost: {total_cost}")
    else:
        print(f"No path found from {start} to {goal}")
# Out:
# Starting A* search from A to G...
# Path found: A -> B -> D -> G
# Total cost: 3

# %%
# Python Program For Minimax algorithm for two-player deterministic games
def minimax(board, depth, maximizing_player):
    # Base case: if depth is 0 or game is over, return evaluation of the board
    if depth == 0 or is_game_over(board):
        return evaluate(board)

    if maximizing_player:
        max_eval = -float('inf')
        for move in get_possible_moves(board):
            new_board = apply_move(board, move)
            eval = minimax(new_board, depth - 1, False)
            max_eval = max(max_eval, eval)
        return max_eval
    else:
        min_eval = float('inf')
        for move in get_possible_moves(board):
            new_board = apply_move(board, move)
            eval = minimax(new_board, depth - 1, True)
            min_eval = min(min_eval, eval)
        return min_eval


def find_best_move(board, depth):
    best_move = None
    max_eval = -float('inf')

    for move in get_possible_moves(board):
        new_board = apply_move(board, move)
        eval = minimax(new_board, depth - 1, False) # Assuming the current player is maximizing
        if eval > max_eval:
            max_eval = eval
            best_move = move
    return best_move


def is_game_over(board):

    return False # Placeholder

def evaluate(board):

    return 0 # Placeholder

def get_possible_moves(board):

    return [] # Placeholder

def apply_move(board, move):

    return board # Placeholder

if __name__ == "__main__":

    initial_game_board = {"state": "some_initial_state"}

    print("Starting Minimax search...")
    search_depth = 3


    best_move = find_best_move(initial_game_board, search_depth)

    if best_move:
        print(f"Best move found: {best_move}")
    else:
        print("No moves available or game is already over.")
# Out:
# Starting Minimax search...
# No moves available or game is already over.
